# %% [markdown]
# <a href="https://colab.research.google.com/github/DestinyOps/DestinyOps/blob/main/Airbnb_Data_reading!!!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q kaggle

# %%
from google.colab import files
from os import environ

# %%
# upload kaggle API key
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b12f0f3f-b039-4348-b7e0-eb3a4d4f73e6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b12f0f3f-b039-4348-b7e0-eb3a4d4f73e6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.makedirs('/root/.kaggle', exist_ok=True)
os.rename('kaggle.json', '/root/.kaggle/kaggle.json')
os.environ['KAGGLE_CONFIG_DIR'] = '/root/.kaggle/'
print(os.environ.get('KAGGLE_CONFIG_DIR'))
# Out:
# /root/.kaggle/

# %%
# fetch kaggle dataset
# !kaggle datasets download -d arianazmoudeh/airbnbopendata
# !unzip airbnbopendata.zip -d /content/
# !unzip "./*.zip" && rm *.zip
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/arianazmoudeh/airbnbopendata
# License(s): ODbL-1.0
# airbnbopendata.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  airbnbopendata.zip
#   inflating: /content/Airbnb_Open_Data.csv

# %%
# !ls
# Out:
# Airbnb_Open_Data.csv  kaggle	 kaggle155Stats  sample_data
# airbnbopendata.zip    kaggle155  kaggleStats155

# %%
import pandas as pd

df = pd.read_csv("./Airbnb_Open_Data.csv", encoding="utf8")
# Out:
# <ipython-input-30-0a93e569ab05>:3: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Airbnb_Open_Data.csv", encoding="utf8")

# %%
df.head()
# Out:
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# ...
